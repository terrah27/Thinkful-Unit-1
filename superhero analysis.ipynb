# %% [markdown]
# <h1>Superhero Exploratory Analysis and Research Proposal</h1>
# <p>The purpose of this projet is to explore and analyze superheros and their characteristics.</p>
# <p>Data Source: https://www.kaggle.com/claudiodavi/superhero-set</p>
# <p>There are two datasets: The first contains characteristics of each superhero and the second lists the superpowers that each hero has.</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [20.0, 7.0]
plt.rcParams.update({'font.size': 22})

sns.set_palette('bright')
sns.set_style('whitegrid')
sns.set_context('talk')

# %%
info_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')

# %%
info_df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
#drop unnamed column
info_df = info_df.drop(['Unnamed: 0'], axis=1)

# %%
#check for null values
info_df.isnull().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
#show rows where publisher is null
info_df[info_df.Publisher.isnull()]
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 46          Astro Boy    Male     brown       -      Black   -99.0       NaN
# 86       Bionic Woman  Female      blue  Cyborg      Black   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 204          Darkside       -         -       -          -   -99.0       NaN
# 244        Ethan Hunt    Male     brown   Human      Brown   168.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 348        Jack Bauer    Male         -       -          -   -99.0       NaN
# 354      Jason Bourne    Male         -   Human          -   -99.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
# 389         King Kong    Male    yellow  Animal      Black    30.5       NaN
# 393      Kool-Aid Man    Male     black       -    No Hair   -99.0       NaN
# 542             Rambo    Male     brown   Human      Black   178.0       NaN
# 658          The Cape    Male         -       -          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 46           -      good   -99.0
# 86           -      good   -99.0
# 138          -         -   -99.0
# 175          -      good   -99.0
# 204          -       bad   -99.0
# 244          -      good   -99.0
# 263          -      good   -99.0
# 286       grey       bad     NaN
# 348          -      good   -99.0
# 354          -      good   -99.0
# 381          -      good   -99.0
# 389          -      good     NaN
# 393        red      good   -99.0
# 542          -      good    83.0
# 658          -      good   -99.0

# %%
# get rid of NaN values for publisher
info_df.Publisher.fillna('Other', inplace=True)

# %%
# -99 is not a valid height or weight so set to NaN
info_df.replace(-99.0, np.nan, inplace=True)

# %%
#update genders if -
info_df.Gender.replace('-', 'Non-Binary', inplace=True)

# %%
#update alignment if -
info_df.Alignment.replace('-', 'None', inplace=True)

# %%
info_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black     NaN
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad     NaN

# %%
#plot number of superheros by gender
sns.countplot(x='Gender', data=info_df);

plt.title('Superheros by Gender')
plt.ylabel('Number of Superheros')
# Out:
# Text(0,0.5,'Number of Superheros')

# %% [markdown]
# Notice there are many more males than females and many more females than non-binary.

# %%
#create new dataframe with only height and weight values that are not null
info_2 = info_df.dropna(subset=['Height', 'Weight'], how='any')
info_2.isnull().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
#keep only columns of interest for plotting
info_2 = info_2[['name', 'Gender', 'Height', 'Weight', 'Alignment']]

# %%
#plot height and weight by gender
sns.pairplot(data=info_2, hue='Gender', size=5)

plt.title('Superhero Heights and Weights by Gender')
plt.show();

# %%
#another height and weight visualization
sns.kdeplot(info_2['Weight'], info_2['Height'])

plt.title('Superheros Height and Weight')
plt.show();

# %%
#plot alignment by gender
sns.countplot(info_2.Gender, hue=info_2.Alignment)

plt.title('Alignment by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Heros')
plt.show();

# %%
#neutral and none groups are both very small...combining into one group as neutral
info_2.Alignment.replace('None', 'neutral', inplace=True)
info_df.Alignment.replace('None', 'neutral', inplace=True)

# %%
info_2.Gender.value_counts()
# Out:
# Male          335
# Female        141
# Non-Binary     14
# Name: Gender, dtype: int64

# %%
info_2.Alignment.value_counts()
# Out:
# good       332
# bad        138
# neutral     20
# Name: Alignment, dtype: int64

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(hspace=0.25, wspace=0.25)
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

fig.add_subplot(221)
sns.swarmplot(x=info_2.Alignment, y=info_2.Weight, hue=info_2.Gender)

fig.add_subplot(222)
sns.stripplot(x=info_2.Alignment, y=info_2.Weight, hue=info_2.Gender, jitter=True)

fig.add_subplot(223)
sns.swarmplot(x=info_2.Gender, y=info_2.Weight, hue=info_2.Alignment)

fig.add_subplot(224)
sns.stripplot(x=info_2.Gender, y=info_2.Weight, hue=info_2.Alignment, jitter=True)

plt.title('Superhero Characteristics')
plt.show;

# %%
#plot number of superheros per publisher
sns.countplot(x="Publisher", data=info_df)

plt.title('Number of Superheros by Publisher')
plt.ylabel('Number of Superheros')
plt.xlabel('Publisher')
plt.xticks(rotation = 90)
plt.show();

# %%
#create new dataframe with only small publishers with < 200 superheros
counts = info_df.Publisher.value_counts()
small_publishers_df = info_df.loc[info_df['Publisher'].isin(counts[counts < 200].index), :]

small_publishers_count = small_publishers_df.Publisher.value_counts()

# %%
#plot only the small publishers
sns.countplot(x="Publisher", data=small_publishers_df)

plt.title('Number of Superheros by Publisher')
plt.ylabel('Number of Superheros')
plt.xlabel('Publisher')
plt.xticks(rotation = 90)
plt.show();

# %%
small_publishers_df.sort_values('Publisher')
# Out:
#                   name  Gender     Eye color                Race  Hair color  \
# 363         Jim Powell    Male             -                   -           -
# 199      Daphne Powell  Female             -                   -           -
# 638   Stephanie Powell  Female             -                   -       Blond
# 364          JJ Powell    Male             -                   -           -
# 208               Dash    Male          blue               Human       Blond
# 235         Elastigirl  Female         brown               Human       Brown
# 321            Hellboy    Male          gold               Demon       Black
# 350          Jack-Jack    Male          blue               Human       Brown
# 698        Violet Parr  Female        violet               Human       Black
# 365      Johann Krauss    Male             -                   -           -
# 411        Liz Sherman  Female             -                   -           -
# 476      Mr Incredible    Male          blue               Human       Blond
# 527           Predator    Male             -              Yautja           -
# 651             T-1000    Male             -             Android           -
# 652              T-800    Male           red              Cyborg           -
# 653              T-850    Male           red              Cyborg           -
# 654                T-X  Female             -              Cyborg           -
# 158   Captain Midnight    Male             -               Human           -
# 139              Buffy  Female         green               Human       Blond
# 1           Abe Sapien    Male          blue       Icthyo Sapien     No Hair
# 23               Angel    Male             -             Vampire           -
# 17               Alien    Male             -     Xenomorph XX121     No Hair
# 731               Yoda    Male         brown      Yoda's species       White
# 306           Han Solo    Male         brown               Human       Brown
# 641       Stormtrooper    Male             -               Human           -
# 418     Luke Skywalker    Male          blue               Human       Blond
# 340      Indiana Jones    Male             -               Human           -
# 207        Darth Vader    Male        yellow              Cyborg     No Hair
# 206         Darth Maul    Male  yellow / red  Dathomirian Zabrak           -
# 557                Rey  Female         hazel               Human       Brown
# ..                 ...     ...           ...                 ...         ...
# 138         Brundlefly    Male             -              Mutant           -
# 372        Judge Dredd    Male             -               Human           -
# 688             Vegeta    Male             -              Saiyan       Black
# 485     Naruto Uzumaki    Male             -               Human           -
# 502      One Punch Man    Male             -               Human     No Hair
# 288               Goku    Male             -              Saiyan           -
# 307            Hancock    Male         brown               Human       Black
# 510         Paul Blart    Male             -               Human           -
# 153  Captain Hindsight    Male             -               Human       Black
# 535                  Q    Male             -       God / Eternal           -
# 352      James T. Kirk    Male         hazel               Human       Brown
# 356    Jean-Luc Picard    Male             -               Human           -
# 380    Kathryn Janeway  Female             -               Human           -
# 209               Data    Male        yellow             Android       Brown
# 629              Spock    Male         brown        Human-Vulcan       Black
# 146      Cameron Hicks    Male             -               Alpha           -
# 276          Gary Bell    Male             -               Alpha           -
# 83         Bill Harken    Male             -               Alpha           -
# 541      Rachel Pirzad  Female             -               Alpha           -
# 493       Nina Theroux  Female             -               Alpha           -
# 174            Chromos    Male         brown                   -  Red / Grey
# 501         Omniscient    Male         brown                   -       Black
# 685       Valerie Hart  Female         hazel                   -       Black
# 152       Captain Epic    Male          blue                   -       Brown
# 434       Master Brood    Male          blue                   -       Black
# 351         James Bond    Male          blue               Human       Blond
# 202            Darkman    Male             -                   -           -
# 453       Minna Murray  Female             -                   -           -
# 14         Alex Mercer    Male             -               Human           -
# 18    Allan Quatermain    Male             -                   -           -
#
#      Height          Publisher   Skin color Alignment  Weight
# 363     NaN        ABC Studios            -      good     NaN
# 199     NaN        ABC Studios            -      good     NaN
# 638     NaN        ABC Studios            -      good     NaN
# 364     NaN        ABC Studios            -      good     NaN
# 208   122.0  Dark Horse Comics            -      good    27.0
# 235   168.0  Dark Horse Comics            -      good    56.0
# 321   259.0  Dark Horse Comics            -      good   158.0
# 350    71.0  Dark Horse Comics            -      good    14.0
# 698   137.0  Dark Horse Comics            -      good    41.0
# 365     NaN  Dark Horse Comics            -      good     NaN
# 411     NaN  Dark Horse Comics            -      good     NaN
# 476   201.0  Dark Horse Comics            -      good   158.0
# 527   213.0  Dark Horse Comics            -       bad   234.0
# 651   183.0  Dark Horse Comics       silver       bad   146.0
# 652     NaN  Dark Horse Comics            -       bad   176.0
# 653     NaN  Dark Horse Comics            -       bad   198.0
# 654     NaN  Dark Horse Comics       silver       bad   149.0
# 158     NaN  Dark Horse Comics            -      good     NaN
# 139   157.0  Dark Horse Comics            -      good    52.0
# 1     191.0  Dark Horse Comics         blue      good    65.0
# 23      NaN  Dark Horse Comics            -      good     NaN
# 17    244.0  Dark Horse Comics        black       bad   169.0
# 731    66.0       George Lucas        green      good    17.0
# 306   183.0       George Lucas            -      good    79.0
# 641   183.0       George Lucas            -       bad     NaN
# 418   168.0       George Lucas            -      good    77.0
# 340   183.0       George Lucas            -      good    79.0
# 207   198.0       George Lucas            -       bad   135.0
# 206   170.0       George Lucas  red / black       bad     NaN
# 557   297.0       George Lucas            -      good     NaN
# ..      ...                ...          ...       ...     ...
# 138   193.0              Other            -   neutral     NaN
# 372   188.0          Rebellion            -      good     NaN
# 688   168.0           Shueisha            -       bad    73.0
# 485   168.0           Shueisha            -      good    54.0
# 502   175.0           Shueisha            -      good    69.0
# 288   175.0           Shueisha            -      good    62.0
# 307   188.0      Sony Pictures            -      good     NaN
# 510   170.0      Sony Pictures            -      good   117.0
# 153     NaN         South Park            -      good     NaN
# 535     NaN          Star Trek            -   neutral     NaN
# 352   178.0          Star Trek            -      good    77.0
# 356     NaN          Star Trek            -      good     NaN
# 380     NaN          Star Trek            -      good     NaN
# 209     NaN          Star Trek            -      good     NaN
# 629   185.0          Star Trek            -      good    81.0
# 146     NaN               SyFy            -      good     NaN
# 276     NaN               SyFy            -      good     NaN
# 83      NaN               SyFy            -      good     NaN
# 541     NaN               SyFy            -      good     NaN
# 493     NaN               SyFy            -      good     NaN
# 174   185.0       Team Epic TV            -       bad    86.0
# 501   180.0       Team Epic TV            -      good    65.0
# 685   175.0       Team Epic TV            -      good    56.0
# 152   188.0       Team Epic TV            -      good     NaN
# 434   183.0       Team Epic TV            -      good    81.0
# 351   183.0        Titan Books            -      good     NaN
# 202     NaN  Universal Studios            -      good     NaN
# 453     NaN          Wildstorm            -      good     NaN
# 14      NaN          Wildstorm            -       bad     NaN
# 18      NaN          Wildstorm            -      good     NaN
#
# [131 rows x 10 columns]

# %%
powers_df.head(10)
# Out:
#       hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0        3-D Man     True                False               False
# 1         A-Bomb    False                 True               False
# 2     Abe Sapien     True                 True               False
# 3       Abin Sur    False                False                True
# 4    Abomination    False                 True               False
# 5        Abraxas    False                False               False
# 6  Absorbing Man    False                False               False
# 7    Adam Monroe    False                 True               False
# 8   Adam Strange    False                False               False
# 9      Agent Bob    False                False               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
# 5                   True            False       False    False
# 6                  False             True        True    False
# 7                  False            False       False    False
# 8                  False            False        True     True
# 9                  False            False       False     True
#
#    Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# 0              False   False     ...             False            False
# 1              False   False     ...             False            False
# 2              False   False     ...             False            False
# 3              False   False     ...             False            False
# 4              False   False     ...             False            False
# 5              False    True     ...             False            False
# 6               True   False     ...             False            False
# 7              False   False     ...             False            False
# 8              False    True     ...             False            False
# 9              False   False     ...             False            False
#
#    Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
# 5       False             False        False          False
# 6       False             False        False          False
# 7       False             False        False          False
# 8       False             False        False          False
# 9       False             False        False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
# 5                  False          False        False       False
# 6                  False          False        False       False
# 7                  False          False        False       False
# 8                  False          False        False       False
# 9                  False          False        False       False
#
# [10 rows x 168 columns]

# %%
# check if any NaN values
powers_df[powers_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [hero_names, Agility, Accelerated Healing, Lantern Power Ring, Dimensional Awareness, Cold Resistance, Durability, Stealth, Energy Absorption, Flight, Danger Sense, Underwater breathing, Marksmanship, Weapons Master, Power Augmentation, Animal Attributes, Longevity, Intelligence, Super Strength, Cryokinesis, Telepathy, Energy Armor, Energy Blasts, Duplication, Size Changing, Density Control, Stamina, Astral Travel, Audio Control, Dexterity, Omnitrix, Super Speed, Possession, Animal Oriented Powers, Weapon-based Powers, Electrokinesis, Darkforce Manipulation, Death Touch, Teleportation, Enhanced Senses, Telekinesis, Energy Beams, Magic, Hyperkinesis, Jump, Clairvoyance, Dimensional Travel, Power Sense, Shapeshifting, Peak Human Condition, Immortality, Camouflage, Element Control, Phasing, Astral Projection, Electrical Transport, Fire Control, Projection, Summoning, Enhanced Memory, Reflexes, Invulnerability, Energy Constructs, Force Fields, Self-Sustenance, Anti-Gravity, Empathy, Power Nullifier, Radiation Control, Psionic Powers, Elasticity, Substance Secretion, Elemental Transmogrification, Technopath/Cyberpath, Photographic Reflexes, Seismic Power, Animation, Precognition, Mind Control, Fire Resistance, Power Absorption, Enhanced Hearing, Nova Force, Insanity, Hypnokinesis, Animal Control, Natural Armor, Intangibility, Enhanced Sight, Molecular Manipulation, Heat Generation, Adaptation, Gliding, Power Suit, Mind Blast, Probability Manipulation, Gravity Control, Regeneration, Light Control, Echolocation, ...]
# Index: []
#
# [0 rows x 168 columns]

# %%
#create new column with sum of each superheros powers
powers_df['sum_powers'] = powers_df.iloc[2:].sum(axis=1)

# %%
#sort by most powers
most_powers = powers_df.sort_values('sum_powers', ascending=False)
most_powers.head()
# Out:
#             hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 563            Spectre     True                 True               False
# 18               Amazo     True                False                True
# 394  Martian Manhunter     True                False               False
# 370    Living Tribunal     True                 True               False
# 388    Man of Miracles    False                 True               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 563                   True            False       False     True
# 18                   False            False        True    False
# 394                  False            False        True     True
# 370                   True            False       False     True
# 388                   True            False       False    False
#
#      Energy Absorption  Flight     ...      Reality Warping  Odin Force  \
# 563               True    True     ...                 True       False
# 18               False    True     ...                False       False
# 394              False    True     ...                False       False
# 370               True    True     ...                 True       False
# 388               True   False     ...                 True       False
#
#      Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 563             False        False          False                  False
# 18              False        False          False                  False
# 394             False        False          False                  False
# 370             False        False          False                  False
# 388             False        False          False                  False
#
#      Vision - Cryo  Omnipresent  Omniscient  sum_powers
# 563          False        False       False        49.0
# 18           False        False       False        44.0
# 394          False        False       False        35.0
# 370          False        False       False        35.0
# 388          False         True        True        34.0
#
# [5 rows x 169 columns]

# %%
#plot superheros by number of powers
sns.countplot(x='sum_powers', data=powers_df)

plt.xlabel('Number of Powers')
plt.ylabel('Number of Superheros')
plt.title('Superheros by Number of Powers')
plt.show();

# %%
#plot superheros with the most powers
most_powers = powers_df[['hero_names', 'sum_powers']].sort_values('sum_powers', ascending=False)

sns.barplot(x=most_powers['hero_names'].head(20),
            y='sum_powers', 
            data=most_powers)

plt.xticks(rotation=80)
plt.title('Superheros with the Most Powers')
plt.xlabel('Superhero')
plt.ylabel('Number of Powers')
plt.show();

# %%
#create a word cloud of superheros with the most powers
from wordcloud import WordCloud

#remove spaces in between name parts - wordcloud splits on whitespace
heronames = most_powers['hero_names'].str.replace(' ', '')

wordcloud = WordCloud().generate(str(heronames.head(20)))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#create new df with number of superheros with each power
sum_row = {col: powers_df[col].sum() for col in powers_df}

sum_df = pd.DataFrame(sum_row, index=["Total"])

sum_df = sum_df.drop('hero_names', axis=1)
sum_df = sum_df.drop('sum_powers', axis=1)


sum_df.tail()
# Out:
#        Agility  Accelerated Healing  Lantern Power Ring  \
# Total      242                  178                  11
#
#        Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# Total                     25               47         257      126
#
#        Energy Absorption  Flight  Danger Sense     ...      Web Creation  \
# Total                 77     212            30     ...                14
#
#        Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# Total               16           2                 9            1
#
#        Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# Total              1                      1              2            2
#
#        Omniscient
# Total           2
#
# [1 rows x 167 columns]

# %%
#transform df
sum_df = sum_df.T
sum_df.head()
# Out:
#                        Total
# Agility                  242
# Accelerated Healing      178
# Lantern Power Ring        11
# Dimensional Awareness     25
# Cold Resistance           47

# %%
sum_df = sum_df.reset_index()
sum_df.rename(columns = {'index':'Powers'}, inplace=True)

# %%
sum_df.columns
# Out:
# Index(['Powers', 'Total'], dtype='object')

# %%
#sort powers by most common
sum_df = sum_df.sort_values('Total', ascending=False)
sum_df.head()
# Out:
#             Powers  Total
# 17  Super Strength    360
# 25         Stamina    289
# 5       Durability    257
# 30     Super Speed    249
# 0          Agility    242

# %%
#plot most common superpowers
sns.barplot(x=sum_df['Powers'].head(20),
            y='Total', 
            data=sum_df)

plt.xticks(rotation=80)
plt.title('Most Common Superpowers')
plt.xlabel('Superpower')
plt.ylabel('Superheros with Power')
plt.show();

# %%
#plot least common superpowers
sns.barplot(x=sum_df['Powers'].tail(20),
            y='Total', 
            data=sum_df)

plt.xticks(rotation=80)
plt.title('Least Common Superpowers')
plt.xlabel('Superpower')
plt.ylabel('Superheros with Power')
plt.show();

# %%
#merge original dataframes together
merged_df = pd.merge(info_df, powers_df, left_on='name', right_on='hero_names', how='inner')

# %%
#view new df head
merged_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black     NaN
#
#            Publisher Skin color Alignment  Weight     ...     Reality Warping  \
# 0      Marvel Comics          -      good   441.0     ...               False
# 1  Dark Horse Comics       blue      good    65.0     ...               False
# 2          DC Comics        red      good    90.0     ...               False
# 3      Marvel Comics          -       bad   441.0     ...               False
# 4      Marvel Comics          -       bad     NaN     ...               False
#
#    Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  sum_powers
# 0                  False          False        False       False         NaN
# 1                  False          False        False       False        16.0
# 2                  False          False        False       False         1.0
# 3                  False          False        False       False         8.0
# 4                  False          False        False       False        14.0
#
# [5 rows x 179 columns]

# %%
merged_df.shape
# Out:
# (660, 179)

# %%
#plot number of superpowers by publisher
sns.barplot(x='Publisher', y='sum_powers', data=merged_df)
plt.xticks(rotation = 90);

plt.title('Number of Powers per Superhero by Publisher')
plt.xlabel('Publisher')
plt.ylabel('Number of Powers')
plt.show();

# %% [markdown]
# <p>There seems to be a very large variation in superheros.  This leads to the question what exactly is a superhero?</p>
#
# <p>According to <a href='https://www.merriam-webster.com/dictionary/superheroSuperhero' target='blank'>Merriam Webster</a> a superhero is fictional hero having extraordinary or superhuman powers or also an exceptionally skillful or successful person.</p>

# %%
#What superhero is from South Park?
merged_df.loc[merged_df['Publisher'] == 'South Park']
# Out:
#                   name Gender Eye color   Race Hair color  Height   Publisher  \
# 140  Captain Hindsight   Male         -  Human      Black     NaN  South Park
#
#     Skin color Alignment  Weight     ...     Reality Warping  Odin Force  \
# 140          -      good     NaN     ...               False       False
#
#      Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 140             False        False          False                  False
#
#      Vision - Cryo  Omnipresent  Omniscient  sum_powers
# 140          False        False       False         3.0
#
# [1 rows x 179 columns]

# %%
#Is he really a superhero?? where is Mario then!?
merged_df.loc[merged_df['Publisher'] == 'Microsoft']
# Out:
#              name Gender Eye color             Race Hair color  Height  \
# 391  Master Chief   Male     brown  Human / Altered      Brown   213.0
#
#      Publisher Skin color Alignment  Weight     ...     Reality Warping  \
# 391  Microsoft          -      good     NaN     ...               False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 391       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  sum_powers
# 391                  False          False        False       False        11.0
#
# [1 rows x 179 columns]

# %%
merged_df.Publisher.value_counts()
# Out:
# Marvel Comics        341
# DC Comics            196
# NBC - Heroes          18
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          13
# Other                 13
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# IDW Publishing         4
# Shueisha               4
# Icon Comics            4
# ABC Studios            4
# Wildstorm              3
# HarperCollins          3
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Microsoft              1
# J. K. Rowling          1
# Universal Studios      1
# South Park             1
# Sony Pictures          1
# Rebellion              1
# Titan Books            1
# Name: Publisher, dtype: int64

# %%
#the small publishers have significantly less superheros so keeping only the superheros from Marvel and DC
merged_df = merged_df[(merged_df['Publisher'] == 'Marvel Comics') | (merged_df['Publisher'] == 'DC Comics')]

# %%
merged_df.Publisher.value_counts()
# Out:
# Marvel Comics    341
# DC Comics        196
# Name: Publisher, dtype: int64

# %%
#t-test comparing number of male heroes to female
print(ttest_ind(merged_df['Gender'] == 'Male', merged_df['Gender'] == 'Female'))
# Out:
# Ttest_indResult(statistic=14.312934728503441, pvalue=1.1846249701575124e-42)

# %%
#t-test comparing number of powers for males and females
ttest_ind(merged_df.dropna()['sum_powers'][merged_df['Gender'] == 'Male'],
          merged_df.dropna()['sum_powers'][merged_df['Gender'] =='Female'])
# Out:
# Ttest_indResult(statistic=2.1723367644180773, pvalue=0.030383646601968094)

# %%
#find mean number of powers by gender
merged_df.groupby('Gender')['sum_powers'].mean()
# Out:
# Gender
# Female        7.934641
# Male          9.904632
# Non-Binary    9.250000
# Name: sum_powers, dtype: float64

# %%
#plot number of superpowers by publisher
sns.barplot(x='Publisher', y='sum_powers', hue='Gender', data=merged_df)

plt.title('Number of Powers per Superhero by Publisher')
plt.xlabel('Publisher')
plt.ylabel('Number of Powers')
plt.show();

# %%
#plot number of powers by Alignment
sns.boxplot(x=merged_df.Alignment, y=merged_df.sum_powers, hue=merged_df.Gender)

plt.title('Number of Powers per Superhero by Alignment')
plt.xlabel('Alignment')
plt.ylabel('Number of Powers')
plt.show();

# %% [markdown]
# <h2>Data Experiment Proposal</h2>
#
# <p>Simply adding up the number of powers is not enough to determine the most powerful superhero.  We also need to take into account the value of each power.  The website, superherodb.com that this dataset was scraped from also has a power bonus for each available power.  Some powers are obviously more valueable than others and should be weighted more heavily.  Also, some heroes have weaknesses that should also be accounted for to find a true ranking of most powerful superhero.</p>
#
# <p>My hypothesis is that once the relative power levels and weaknesses are accounted for, female superheroes are stronger than male superheroes eventhough they are generally given a lower number of powers than male superheroes.</p>

# %% [markdown]
# <h4>Rollout Plan</h4>
#
# <p>
# Write a scraper to collect more data from superherodb.com, making sure to include the power bonus values for each power and any weaknesses each superhero may have.  After collecting the additional information, explore the data and calculate statistics.
# </p>

# %% [markdown]
# <h4>Evaluation Plan</h4>
#
# <p>
# Rank the superheroes by the relative power levels, and not just by the total number of powers.  Find the mean power level and standard deviation for each group of heroes, male and female, and compare the two groups.  And finally compare the males to females to determine the most powerful gender.
# </p>
